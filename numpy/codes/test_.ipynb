# %%
print(0b10)
print("let's go")
print('let\'s go')
print('''let's go''')
print("My name is %s" %("duanhaobin"))
# Out:
# 2
# let's go
# let's go
# let's go
# My name is duanhaobin

# %%
hex(1000000)
# Out:
# '0xf4240'
