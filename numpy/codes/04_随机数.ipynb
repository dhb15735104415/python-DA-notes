# %%
''' 
    Numpy随机数

    numpy.random包含多种概率分布的随机样本，是数据分析辅助的重点工具之一
'''
# Out:
# ' \n    Numpy随机数\n\n    numpy.random包含多种概率分布的随机样本，是数据分析辅助的重点工具之一\n'

# %%
import numpy as np

# 随机数生成
print(np.random.normal(size=4*4))  # 生成一个标准正太分布的4*4样本值
# Out:
# [ 0.66187522 -0.19434033  1.10370935  0.50961627  0.96669514  1.57217402
#  -0.95829102  0.80279811 -0.34854902 -0.58390247 -0.51363767 -0.05538859
#   1.46125226  0.13843089 -0.27295443 -1.08531044]

# %%
# numpy.random.rand(d0, d1, ..., dn)：生成一个[0,1)之间的随机浮点数或N维浮点数组 —— 均匀分布

a = np.random.rand()
print(a,type(a))  # 生成一个随机浮点数[0,1)

b = np.random.rand(4)  # 生成形状为4的一维数组
print('生成形状为4的一维数组',b)

c = np.random.rand(4,4)
print('生成形状为4*4的二维数组', c)   # 生成形状为4*4的二维数组

# 可以进行数学计算
print('乘以100后:',c*100)
# Out:
# 0.1663106135011977 <class 'float'>
# 生成形状为4的一维数组 [0.49133153 0.57350098 0.42400936 0.7177676 ]
# 生成形状为4*4的二维数组 [[0.85451882 0.78341092 0.52718202 0.40902368]
#  [0.01923275 0.49587207 0.42176548 0.40281092]
#  [0.72722737 0.71407664 0.8718098  0.3774519 ]
#  [0.36359973 0.48290309 0.58219032 0.06129018]]
# 乘以100后: [[85.45188177 78.34109202 52.71820203 40.90236803]
#  [ 1.92327462 49.58720653 42.17654834 40.28109151]
#  [72.72273663 71.40766368 87.18097962 37.74518975]
#  [36.35997343 48.29030862 58.21903249  6.12901822]]

# %%
# numpy.random.randint(low, high=None, size=None, dtype='l')：生成一个整数或N维整数数组
# 若high不为None时，取[low,high)之间随机整数，否则取值[0,low)之间随机整数，且high必须大于low 
# dtype参数：只能是int类型 

# low=2：生成1个[0,2)之间随机整数
int1 = np.random.randint(2)
print('low=2：生成1个[0,2)之间随机整数:',int1)

# low=2,high=5 ：生成1个[2,5)之间随机整数
int2 = np.random.randint(2,5)
print('low=2,high=5 ：生成1个[2,5)之间随机整数:',int2)

# low=2,size=5 ：生成5个[0,2)之间随机整数
int_arr1 = np.random.randint(2,size=5)
print(f'low=2,size=5 ：生成5个[0,2)之间随机整数:{int_arr1},类型为:',type(int_arr1))

# low=2,high=6,size=8：生成8个[2,6)之间随机整数
int_arr2 = np.random.randint(2,6,size=8)
print('low=2,high=6,size=8：生成8个[2,6)之间随机整数:',int_arr2)

# low=2,size=(2,3)：生成一个2x3整数数组,取数范围：[0,2)随机整数 
int_arr3 = np.random.randint(2,size=(2,3))
print('low=2,size=(2,3)：生成一个2x3整数数组:',int_arr3)

# low=2,high=6,size=(2,3)：生成一个2*3整数数组,取值范围：[2,6)随机整数
int_arr4 = np.random.randint(2,6,size=(2,3))
print('low=2,high=6,size=(2,3)：生成一个2*3整数数组:',int_arr4)
# Out:
# low=2：生成1个[0,2)之间随机整数: 0
# low=2,high=5 ：生成1个[2,5)之间随机整数: 4
# low=2,size=5 ：生成5个[0,2)之间随机整数:[0 1 1 1 1],类型为: <class 'numpy.ndarray'>
# low=2,high=6,size=8：生成8个[2,6)之间随机整数: [3 5 3 5 4 4 5 4]
# low=2,size=(2,3)：生成一个2x3整数数组: [[0 0 1]
#  [1 1 1]]
# low=2,high=6,size=(2,3)：生成一个2*3整数数组: [[4 2 4]
#  [4 4 2]]

# %%
#  numpy.random.randn(d0, d1, ..., dn)：生成一个浮点数或N维浮点数组 —— 正态分布
import matplotlib.pyplot  as plt
# %matplotlib inline

samples1 = np.random.randn(1000)
samples2 = np.random.randn(1000)
plt.scatter(samples1,samples2)

ar = np.random.randn(5,4)
print('randn(5,4)生成5行4列的数组:',ar,sep='\n')
# Out:
# randn(5,4)生成5行4列的数组:
# [[-0.25058279  0.08516517 -0.66703041  1.29150898]
#  [-0.46522965 -0.38601651  0.00441574 -1.73064243]
#  [-0.4050359  -0.86653216 -0.42112064  1.66633095]
#  [ 1.51054128 -0.39611728  0.83566653  0.41857433]
#  [ 0.29761396 -0.11703508 -1.4686391  -1.37338167]]
