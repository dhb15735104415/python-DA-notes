# %%
'''
    参考:https://blog.csdn.net/luanpeng825485697/article/details/78508819
    Matplotlib简介及图表窗口

    Matplotlib → 一个python版的matlab绘图接口，以2D为主，支持python、numpy、pandas基本数据结构，
    运营高效且有较丰富的图表库
    
   # %matplotlib作用

    是在使用jupyter notebook 或者 jupyter qtconsole的时候，才会经常用到%matplotlib，
    也就是说那一份代码可能就是别人使用jupyter notebook 或者 jupyter qtconsole进行编辑的。
    
    而%matplotlib具体作用是当你调用matplotlib.pyplot的绘图函数plot()进行绘图的时候，
    或者生成一个figure画布的时候，可以直接在你的python console里面生成图像。
    
    
'''
# Out:
# '\n    参考:https://blog.csdn.net/luanpeng825485697/article/details/78508819\n    Matplotlib简介及图表窗口\n\n    Matplotlib → 一个python版的matlab绘图接口，以2D为主，支持python、numpy、pandas基本数据结构，\n    运营高效且有较丰富的图表库\n'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# 图表窗口1 → plt.show()

plt.plot(np.random.rand(10))
plt.show()  # 直接生成图表

# %%
# 图表窗口2 → 魔法函数，嵌入图表  
# %matplotlib inline 可以在Ipython编译器里直接使用，功能是可以内嵌绘图，并且可以省略掉plt.show()这一步。

# %matplotlib inline   
# 记住%和matplotlib之间没有空格

x = np.random.randn(1000)
y = np.random.randn(1000)
plt.scatter(x,y)  #  散点图

# %%
# 图表窗口3 → 魔法函数，弹出可交互的matplotlib窗口

# %matplotlib notebook
s = pd.Series(np.random.randn(100))
s.plot(style = 'k--o',figsize=(10,5))
# 可交互的matplotlib窗口，不用plt.show()
# 可做一定调整
# Out:
# <div id='0e1cfde7-f6a5-4f1a-92f7-da30c2603a32'></div>

# %%
# 图表窗口4 → 魔法函数，弹出matplotlib控制台

# %matplotlib qt5

#plt.gcf().clear()  
# 每次清空图表内内容
df = pd.DataFrame(np.random.rand(50,2),columns=['A','B'])
df.hist(figsize=(12,5),color='g',alpha=0.8)

# 可交互性控制台
# 如果已经设置了显示方式（比如notebook），需要重启然后再运行魔法函数
# 网页嵌入的交互性窗口 和 控制台，只能显示一个

#plt.close()    
# 关闭窗口
# Out:
# ...
# <div id='cd380faa-09ed-41ca-ba38-c1530403b5d3'></div>
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002C8BBFD95C0>,
# ...
#       dtype=object)
